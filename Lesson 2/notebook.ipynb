# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import pandas as pd

# %%
main_link = 'https://hh.ru'
params = {'text': 'Data scientist'}
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36',
    'Accept': '*/*'}

# %%
response = requests.get(main_link + '/search/vacancy', params=params, headers=headers)
soup = bs(response.text, 'lxml')

jobs_block = soup.find('div', {'class': 'vacancy-serp'})
jobs_list = jobs_block.find_all('div', {'data-qa': 'vacancy-serp__vacancy'})

jobs = []

# %%
for job in jobs_list:
    job_data = {}
    tag_link = job.find('span', {'class': 'g-user-content'})
    name = tag_link.a.text
    link = tag_link.a['href']

    tag_price = job.find('div', {'class': 'vacancy-serp-item__sidebar'})
    price = tag_price.text

    job_data['name'] = name
    job_data['price'] = price
    link_end = link.find('?')
    job_data['link'] = link[0:link_end]
    job_data['site'] = main_link

    jobs.append(job_data)

# %%
pd.DataFrame(jobs, columns=['name', 'price', 'link', 'site'])
# Out:
#                                                  name                 price  \
# 0                               Python Data Scientist       от 150 000 руб.
# 1                               Senior Data Scientist       от 300 000 руб.
# 2                                      Data Scientist       от 130 000 руб.
# 3                                      Data scientist       до 150 000 руб.
# 4                                      Data Scientist       от 110 000 руб.
# 5     Middle/Senior data scientist (fraud prevention)  140 000-220 000 руб.
# 6                                      Data Scientist
# 7                           Data Scientist (Limassol)
# 8   Аналитик - эконометрист / Data scientist (Juni...
# 9                               Data Scientist (CLTV)
# 10                                     Data scientist
# 11                                     Data Scientist
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                                     Data Scientist
# 15                                     Data Scientist
# 16                                     Data Scientist
# 17                                     Data Scientist
# 18                                     Data Scientist       от 100 000 руб.
# 19        Специалист Computer Vision (Data Scientist)  120 000-220 000 руб.
# 20                              Middle Data Scientist
# 21                              Senior data scientist
# 22  Senior data scientist (руководитель группы ant...
# 23                       Middle/Senior Data Scientist
# 24            Quantitative Researcher (Deep Research)
# 25                                     Data Scientist
# 26                                    Бизнес-аналитик  120 000-180 000 руб.
# 27                   Data Scientist (Computer Vision)
# 28                                     Data scientist
# 29                                     Data scientist
# 30                                     Data scientist
# 31                                     Data scientist
# 32                                     Data scientist       от 150 000 руб.
# 33                                     Data Scientist
# 34         Senior Big Data инженер (Machine Learning)
# 35                                        Тестировщик
# 36                                     Data Scientist
# 37       Python-разработчик (Middle Python Developer)       до 230 000 руб.
# 38                                     Data Scientist
# 39                                     Data Scientist
# 40                              Senior Data Scientist
# 41                                     Data Scientist
# 42                              Senior Data Scientist
# 43                                     Data Scientist
# 44                                     Data Scientist
# 45                                     Data Scientist
# 46                                     Data Scientist
# 47                                     Data Scientist
#
#                               link           site
# 0   https://hh.ru/vacancy/36916080  https://hh.ru
# 1   https://hh.ru/vacancy/37294434  https://hh.ru
